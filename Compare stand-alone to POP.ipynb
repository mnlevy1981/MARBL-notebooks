# %% [markdown]
# ### Did we correctly capture POP forcing data?
#
# Hopefully the dataset created from [Forcing Data (with xarray).ipynb](https://github.com/mnlevy1981/MARBL-notebooks/blob/master/Forcing%20Data%20(with%20xarray).ipynb) produces the same MARBL output in its five columns as we find in the POP datasets.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import MARBL_pop_comp

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (18.0, 10.0); # Large figures
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
MARBL_pop_comp.compare_POP_and_MARBL()
# Out:
# Opening /glade/scratch/mlevy/g.e22b2.G1850ECO.T62_g17.gen_single_col.nstep_out/run/g.e22b2.G1850ECO.T62_g17.gen_single_col.nstep_out.pop.h.0001-01-01-05040.nc
# Opening /glade/u/home/mlevy/codes/MARBL/tests/regression_tests/compute_cols/history_1inst.nc
# zt is in MARBL data set but not POP
# zw is in MARBL data set but not POP
# PO4_SFLUX is in MARBL data set but not POP
# NO3_SFLUX is in MARBL data set but not POP
# SiO3_SFLUX is in MARBL data set but not POP
# NH4_SFLUX is in MARBL data set but not POP
# Fe_SFLUX is in MARBL data set but not POP
# Lig_SFLUX is in MARBL data set but not POP
# O2_SFLUX is in MARBL data set but not POP
# DIC_SFLUX is in MARBL data set but not POP
# DIC_ALT_CO2_SFLUX is in MARBL data set but not POP
# ALK_SFLUX is in MARBL data set but not POP
# ALK_ALT_CO2_SFLUX is in MARBL data set but not POP
# DOC_SFLUX is in MARBL data set but not POP
# DON_SFLUX is in MARBL data set but not POP
# DOP_SFLUX is in MARBL data set but not POP
# DOPr_SFLUX is in MARBL data set but not POP
# DONr_SFLUX is in MARBL data set but not POP
# DOCr_SFLUX is in MARBL data set but not POP
# zooC_SFLUX is in MARBL data set but not POP
# spChl_SFLUX is in MARBL data set but not POP
# spC_SFLUX is in MARBL data set but not POP
# spP_SFLUX is in MARBL data set but not POP
# spFe_SFLUX is in MARBL data set but not POP
# spCaCO3_SFLUX is in MARBL data set but not POP
# diatChl_SFLUX is in MARBL data set but not POP
# diatC_SFLUX is in MARBL data set but not POP
# diatP_SFLUX is in MARBL data set but not POP
# diatFe_SFLUX is in MARBL data set but not POP
# diatSi_SFLUX is in MARBL data set but not POP
# diazChl_SFLUX is in MARBL data set but not POP
# diazC_SFLUX is in MARBL data set but not POP
# diazP_SFLUX is in MARBL data set but not POP
# diazFe_SFLUX is in MARBL data set but not POP
#
# PV_O2
# ----
# Col 3 (no sun)
#   * max diff: 9.323979864697728e-20
#   * rel diff: 1.1463506617092087e-12
#
# PV_CO2
# ----
# Col 3 (no sun)
#   * max diff: 8.92560968169219e-20
#   * rel diff: 1.1465021764546458e-12
#
# FG_CO2
# ----
# Col 3 (no sun)
#   * max diff: 2.1130825056034624e-19
#   * rel diff: 1.1465188505605905e-12
#
# FG_ALT_CO2
# ----
# Col 3 (no sun)
#   * max diff: 2.1130825056034624e-19
#   * rel diff: 1.1465188505605905e-12
#
# NHx_SURFACE_EMIS
# ----
# Col 3 (no sun)
#   * max diff: 8.466686323556076e-25
#   * rel diff: 1.1465913698523852e-12
#
# Jint_Ctot
# ----
# Col 2 (5 PAR subcols)
#   * max diff: 1.734723475976807e-18
#   * rel diff: 0.5267489711934157
# Col 3 (no sun)
#   * max diff: 1.6940658945086007e-21
#   * rel diff: 0.04938271604938271
# Col 4 (high Fe)
#   * max diff: 2.710505431213761e-20
#   * rel diff: 0.00684931506849315
# Col 5 (shallow)
#   * max diff: 8.673617379884035e-19
#   * rel diff: 0.09090909090909091
#
# Jint_Ntot
# ----
# Col 1 (OMZ)
#   * max diff: 4.336808689942018e-19
#   * rel diff: 0.43243243243243246
# Col 2 (5 PAR subcols)
#   * max diff: 4.54009659728305e-19
#   * rel diff: 1.046875
# Col 4 (high Fe)
#   * max diff: 2.710505431213761e-20
#   * rel diff: 0.43243243243243246
#
# Jint_Ptot
# ----
# Col 2 (5 PAR subcols)
#   * max diff: 1.3552527156068805e-20
#   * rel diff: 1.1743119266055047
# Col 4 (high Fe)
#   * max diff: 3.494010907423989e-21
#   * rel diff: 0.4647887323943662
# Col 5 (shallow)
#   * max diff: 1.3552527156068805e-20
#   * rel diff: NaN (POP is all zeroes)
#
# Jint_Sitot
# ----
# Col 5 (shallow)
#   * max diff: 2.710505431213761e-20
#   * rel diff: 1.0
#
# Jint_Fetot
# ----
# Col 2 (5 PAR subcols)
#   * max diff: 5.293955920339377e-23
#   * rel diff: NaN (POP is all zeroes)
# Col 3 (no sun)
#   * max diff: 1.0339757656912846e-25
#   * rel diff: 0.2
# Col 4 (high Fe)
#   * max diff: 2.6469779601696886e-23
#   * rel diff: 1.0
#
# O2_CONSUMPTION
# ----
# Col 1 (OMZ)
#   * max diff: 4.6453814239577374e-08
#   * rel diff: 0.003939332147736644
# Skipping PAR_avg due to dimension mis-match
# Skipping graze_auto_TOT due to dimension mis-match
# Skipping photoC_TOT due to dimension mis-match
# Skipping photoC_NO3_TOT due to dimension mis-match
# /glade/work/mlevy/codes/MARBL-notebooks/MARBL_pop_comp.py:35: RuntimeWarning: All-NaN axis encountered
#   abs_err = np.nanmax(np.abs(pop_data - marbl_data))
# /glade/work/mlevy/codes/MARBL-notebooks/MARBL_pop_comp.py:36: RuntimeWarning: All-NaN axis encountered
#   denom = np.nanmax(np.abs(pop_data))
# Skipping sp_Qp due to dimension mis-match
# Skipping photoC_sp due to dimension mis-match
# Skipping photoC_NO3_sp due to dimension mis-match
# Skipping photoFe_sp due to dimension mis-match
# Skipping photoNO3_sp due to dimension mis-match
# Skipping photoNH4_sp due to dimension mis-match
# Skipping DOP_sp_uptake due to dimension mis-match
# Skipping PO4_sp_uptake due to dimension mis-match
# Skipping graze_sp due to dimension mis-match
# Skipping graze_sp_poc due to dimension mis-match
# Skipping graze_sp_doc due to dimension mis-match
# Skipping graze_sp_zootot due to dimension mis-match
# Skipping graze_sp_zoo due to dimension mis-match
# Skipping sp_loss due to dimension mis-match
# Skipping sp_loss_poc due to dimension mis-match
# Skipping sp_loss_doc due to dimension mis-match
# Skipping sp_agg due to dimension mis-match
# Skipping sp_CaCO3_form due to dimension mis-match
# Skipping diat_Qp due to dimension mis-match
# Skipping photoC_diat due to dimension mis-match
# Skipping photoC_NO3_diat due to dimension mis-match
# Skipping photoFe_diat due to dimension mis-match
# Skipping photoNO3_diat due to dimension mis-match
# Skipping photoNH4_diat due to dimension mis-match
# Skipping DOP_diat_uptake due to dimension mis-match
# Skipping PO4_diat_uptake due to dimension mis-match
# Skipping graze_diat due to dimension mis-match
# Skipping graze_diat_poc due to dimension mis-match
# Skipping graze_diat_doc due to dimension mis-match
# Skipping graze_diat_zootot due to dimension mis-match
# Skipping graze_diat_zoo due to dimension mis-match
# Skipping diat_loss due to dimension mis-match
# Skipping diat_loss_poc due to dimension mis-match
# Skipping diat_loss_doc due to dimension mis-match
# Skipping diat_agg due to dimension mis-match
# Skipping diat_bSi_form due to dimension mis-match
# Skipping diaz_Qp due to dimension mis-match
# Skipping photoC_diaz due to dimension mis-match
# Skipping photoC_NO3_diaz due to dimension mis-match
# Skipping photoFe_diaz due to dimension mis-match
# Skipping photoNO3_diaz due to dimension mis-match
# Skipping photoNH4_diaz due to dimension mis-match
# Skipping DOP_diaz_uptake due to dimension mis-match
# Skipping PO4_diaz_uptake due to dimension mis-match
# Skipping graze_diaz due to dimension mis-match
# Skipping graze_diaz_poc due to dimension mis-match
# Skipping graze_diaz_doc due to dimension mis-match
# Skipping graze_diaz_zootot due to dimension mis-match
# Skipping graze_diaz_zoo due to dimension mis-match
# Skipping diaz_loss due to dimension mis-match
# Skipping diaz_loss_poc due to dimension mis-match
# Skipping diaz_loss_doc due to dimension mis-match
# Skipping diaz_agg due to dimension mis-match
# Skipping diaz_Nfix due to dimension mis-match
# Skipping bSi_form due to dimension mis-match
# Skipping CaCO3_form due to dimension mis-match
# Skipping Nfix due to dimension mis-match
# Skipping zoo_loss due to dimension mis-match
# Skipping zoo_loss_poc due to dimension mis-match
# Skipping zoo_loss_doc due to dimension mis-match
# Skipping graze_zoo due to dimension mis-match
# Skipping graze_zoo_poc due to dimension mis-match
# Skipping graze_zoo_doc due to dimension mis-match
# Skipping graze_zoo_zootot due to dimension mis-match
# Skipping graze_zoo_zoo due to dimension mis-match
# Skipping x_graze_zoo due to dimension mis-match
# Skipping TEND_PO4 because MARBL and POP compute values very differently
# Skipping TEND_NO3 because MARBL and POP compute values very differently
# Skipping TEND_SiO3 because MARBL and POP compute values very differently
# Skipping TEND_NH4 because MARBL and POP compute values very differently
# Skipping TEND_Fe because MARBL and POP compute values very differently
# Skipping TEND_Lig because MARBL and POP compute values very differently
# Skipping TEND_O2 because MARBL and POP compute values very differently
# Skipping TEND_DIC because MARBL and POP compute values very differently
# Skipping TEND_DIC_ALT_CO2 because MARBL and POP compute values very differently
# Skipping TEND_ALK because MARBL and POP compute values very differently
# Skipping TEND_ALK_ALT_CO2 because MARBL and POP compute values very differently
# Skipping TEND_DOC because MARBL and POP compute values very differently
# Skipping TEND_DON because MARBL and POP compute values very differently
# Skipping TEND_DOP because MARBL and POP compute values very differently
# Skipping TEND_DOPr because MARBL and POP compute values very differently
# Skipping TEND_DONr because MARBL and POP compute values very differently
# Skipping TEND_DOCr because MARBL and POP compute values very differently
# Skipping TEND_zooC because MARBL and POP compute values very differently
# Skipping TEND_spChl because MARBL and POP compute values very differently
# Skipping TEND_spC because MARBL and POP compute values very differently
# Skipping TEND_spP because MARBL and POP compute values very differently
# Skipping TEND_spFe because MARBL and POP compute values very differently
# Skipping TEND_spCaCO3 because MARBL and POP compute values very differently
# Skipping TEND_diatChl because MARBL and POP compute values very differently
# Skipping TEND_diatC because MARBL and POP compute values very differently
# Skipping TEND_diatP because MARBL and POP compute values very differently
# Skipping TEND_diatFe because MARBL and POP compute values very differently
# Skipping TEND_diatSi because MARBL and POP compute values very differently
# Skipping TEND_diazChl because MARBL and POP compute values very differently
# Skipping TEND_diazC because MARBL and POP compute values very differently
# Skipping TEND_diazP because MARBL and POP compute values very differently
# Skipping TEND_diazFe because MARBL and POP compute values very differently
